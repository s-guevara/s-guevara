# %%
import pandas as pd
import numpy as np
import wbgapi as wb
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2009-2019

# %%
data = pd.read_csv('data/raw_data/globalterrorismdb_0221dist_GTDdata.csv')

# %%
# Reduce to selected columns
data = data[['iyear','imonth','country_txt','region_txt','provstate','city','latitude','longitude','success',
       'attacktype1_txt','targtype1_txt','targsubtype1_txt','gname','nperps','weaptype1_txt','nkill','nwound']]
data = data.rename(columns = {'iyear':'Year', 'imonth':'Month', 'country_txt':'Country', 'region_txt':'Region', 
                          'provstate':'State', 'city':'City', 'latitude':'Latitude', 'longitude':'Longitude', 
                          'success':'Success', 'attacktype1_txt':'Type of Attack', 'targtype1_txt':'Type of Target',
                          'targsubtype1_txt':'Target Subcategory', 'gname':'Group Name', 'nperps':'Number of Perpetrators',
                          'weaptype1_txt':'Type of Weapon', 'nkill':'Fatalities','nwound':'Wounded'})


# 2009-2019 Data
df = data[data['Year'] >= 2009]
df.head()
# Out:
#        Year  Month                   Country                      Region  \
# 90160  2009      1                   Somalia          Sub-Saharan Africa
# 90161  2009      1                      Iraq  Middle East & North Africa
# 90162  2009      1                      Iraq  Middle East & North Africa
# 90163  2009      1                      Iraq  Middle East & North Africa
# 90164  2009      1  West Bank and Gaza Strip  Middle East & North Africa
#
#            State       City   Latitude  Longitude  Success     Type of Attack  \
# 90160   Banaadir  Mogadishu   2.059819  45.326115        1  Bombing/Explosion
# 90161    Nineveh      Mosul  36.354145  43.143570        1      Armed Assault
# 90162     Kirkuk     Kirkuk  35.452110  44.375465        1  Bombing/Explosion
# 90163     Diyala    Mandali  33.744999  45.545616        1  Bombing/Explosion
# 90164  West Bank  Bayt Umar  31.626705  35.104969        1  Bombing/Explosion
#
#                     Type of Target                       Target Subcategory  \
# 90160  Private Citizens & Property                Race/Ethnicity Identified
# 90161  Private Citizens & Property  Laborer (General)/Occupation Identified
# 90162                       Police          Police Security Forces/Officers
# 90163  Private Citizens & Property             Unnamed Civilian/Unspecified
# 90164               Transportation                 Bus (excluding tourists)
#
#        Group Name  Number of Perpetrators Type of Weapon  Fatalities  Wounded
# 90160  Al-Shabaab                   -99.0     Explosives         8.0     10.0
# 90161     Unknown                   -99.0       Firearms         1.0      0.0
# 90162     Unknown                   -99.0     Explosives         0.0      0.0
# 90163     Unknown                   -99.0     Explosives         0.0      3.0
# 90164     Unknown                   -99.0     Explosives         0.0      0.0

# %%
df.to_csv('data/initial.csv', index=False)

# %% [markdown]
# ## Capital Cities

# %%
# Collect capital cities
capitals = pd.read_csv('data/raw_data/countries_capitals.csv')
capitals = capitals[['name','iso3','capital','latitude', 'longitude']].rename(columns={'name':'Country','iso3':'Code','capital':'Capital'})

# Rename countries to match between gtd data and country capitals
capitals = capitals.replace(['Korea South','Bahamas The','Bosnia and Herzegovina','Congo The Democratic Republic Of The',
                 "Cote D'Ivoire (Ivory Coast)",'Croatia (Hrvatska)','Netherlands The','Papua new Guinea',
                 'Trinidad And Tobago'],
                 ['South Korea','Bahamas','Bosnia-Herzegovina','Democratic Republic of the Congo','Ivory Coast',
                 'Croatia','Netherlands','Papua New Guinea','Trinidad and Tobago'])
df = df.replace(['Republic of the Congo','Slovak Republic'],['Congo','Slovakia'])

# Merge to capital cities to gtd data
capitals_df = df.merge(capitals, on='Country')

# Reorganize columns
gtd_capitals = capitals_df[['Country','Code','Region','State','Capital','City','Year','Month',
                            'Latitude','Longitude','Success','Type of Attack','Type of Target',
                            'Target Subcategory','Group Name','Number of Perpetrators',
                            'Type of Weapon','Fatalities','Wounded']]
gtd_capitals.head()
# Out:
#    Country Code              Region     State    Capital        City  Year  \
# 0  Somalia  SOM  Sub-Saharan Africa  Banaadir  Mogadishu   Mogadishu  2009
# 1  Somalia  SOM  Sub-Saharan Africa       Bay  Mogadishu   Burhakaba  2009
# 2  Somalia  SOM  Sub-Saharan Africa       Bay  Mogadishu   Burhakaba  2009
# 3  Somalia  SOM  Sub-Saharan Africa  Banaadir  Mogadishu   Mogadishu  2009
# 4  Somalia  SOM  Sub-Saharan Africa      Gedo  Mogadishu  Garbaharey  2009
#
#    Month  Latitude  Longitude  Success               Type of Attack  \
# 0      1  2.059819  45.326115        1            Bombing/Explosion
# 1      1  2.798167  44.078560        1  Hostage Taking (Kidnapping)
# 2      1  2.798167  44.078560        1  Hostage Taking (Kidnapping)
# 3      1  2.059819  45.326115        1                Armed Assault
# 4      1  3.327280  42.218563        1            Bombing/Explosion
#
#                 Type of Target  \
# 0  Private Citizens & Property
# 1         Government (General)
# 2         Government (General)
# 3      Government (Diplomatic)
# 4         Government (General)
#
#                                   Target Subcategory  \
# 0                          Race/Ethnicity Identified
# 1  Government Personnel (excluding police, military)
# 2  Government Personnel (excluding police, military)
# 3  International Organization (peacekeeper, aid a...
# 4  Government Personnel (excluding police, military)
#
#                              Group Name  Number of Perpetrators  \
# 0                            Al-Shabaab                   -99.0
# 1                  Somali Islamic Front                   -99.0
# 2  23 May Democratic Alliance (Algeria)                   -99.0
# 3                               Unknown                   -99.0
# 4                            Al-Shabaab                   -99.0
#
#   Type of Weapon  Fatalities  Wounded
# 0     Explosives         8.0     10.0
# 1        Unknown         0.0      0.0
# 2        Unknown         0.0      0.0
# 3       Firearms         1.0      0.0
# 4     Explosives         4.0      0.0

# %% [markdown]
# ## WB data: Income Level

# %%
# Collect Population & GDP data
wb_df = wb.data.DataFrame(
    ['NY.GDP.PCAP.CD', 'SP.POP.TOTL'], mrv=11, columns = 'series', labels = True).reset_index().set_index(
    'economy').join(wb.economy.DataFrame()['incomeLevel']).drop('time', axis=1)
wb_df = wb_df.rename(columns={'NY.GDP.PCAP.CD':'GDP','SP.POP.TOTL':'Population','incomeLevel':'Income Level',
                             'Time':'Year'})
wb_df['Year'] = pd.to_numeric(wb_df['Year'])

# Convert index to column
wb_df = wb_df.reset_index().rename(columns={'index':'Code'}).drop('Country', axis = 1)
wb_df.head()
# Out:
#   Code  Year           GDP  Population Income Level
# 0  ABW  2019           NaN    106314.0          HIC
# 1  ABW  2018           NaN    105845.0          HIC
# 2  ABW  2017  29007.693003    105366.0          HIC
# 3  ABW  2016  28281.350482    104872.0          HIC
# 4  ABW  2015  27980.880695    104341.0          HIC

# %%
# merge with gtd_capitals for new dataframe
gtd_wb = wb_df.merge(gtd_capitals, on=['Code', 'Year'])
gtd_wb = gtd_wb.replace(['LIC','UMC','LMC','HIC'],['Low Income','Upper Middle','Lower Middle','High Income'])

# Calculate number of casualties
gtd_wb['Casualties'] = gtd_wb.Fatalities + gtd_wb.Wounded
gtd_wb.head()
# Out:
#   Code  Year         GDP  Population Income Level      Country      Region  \
# 0  AFG  2019  507.103432  38041754.0   Low Income  Afghanistan  South Asia
# 1  AFG  2019  507.103432  38041754.0   Low Income  Afghanistan  South Asia
# 2  AFG  2019  507.103432  38041754.0   Low Income  Afghanistan  South Asia
# 3  AFG  2019  507.103432  38041754.0   Low Income  Afghanistan  South Asia
# 4  AFG  2019  507.103432  38041754.0   Low Income  Afghanistan  South Asia
#
#       State Capital                  City  ...  Success  \
# 0  Kandahar   Kabul              Mandozai  ...        1
# 1    Takhar   Kabul  Dashti Qala district  ...        1
# 2   Baghlan   Kabul           Khwaja Khan  ...        1
# 3     Herat   Kabul            Islam Kala  ...        1
# 4    Ghazni   Kabul                Ghazni  ...        1
#
#                 Type of Attack               Type of Target  \
# 0            Bombing/Explosion                     Military
# 1                Armed Assault                       Police
# 2  Hostage Taking (Kidnapping)  Private Citizens & Property
# 3            Bombing/Explosion                     Military
# 4                      Unknown                       Police
#
#                                 Target Subcategory Group Name  \
# 0    Military Barracks/Base/Headquarters/Checkpost    Taliban
# 1                  Police Security Forces/Officers    Taliban
# 2                     Political Party Member/Rally    Taliban
# 3                                             NATO    Taliban
# 4  Police Building (headquarters, station, school)    Taliban
#
#   Number of Perpetrators Type of Weapon Fatalities  Wounded Casualties
# 0                  -99.0     Explosives        5.0      6.0       11.0
# 1                  -99.0       Firearms        5.0      3.0        8.0
# 2                  -99.0       Firearms        NaN      NaN        NaN
# 3                    2.0     Explosives        1.0      1.0        2.0
# 4                  -99.0        Unknown       10.0      5.0       15.0
#
# [5 rows x 23 columns]

# %%
gtd_wb.to_csv('data/gtd_global.csv', index=False)

# %% [markdown]
# ## "Extremists"

# %%
# Collect all groups that had the label "extremists"
extrem_df = gtd_wb[gtd_wb['Group Name'].str.contains('extrem')]

# Collect columns
extrem_df = extrem_df[['Year','Code','Country','Region','Income Level','Group Name',
                         'Fatalities','Wounded','Casualties','Type of Target']]

# Categorize the listed extremist groups and set in new column
original = extrem_df['Group Name'].unique().tolist()
type_new = ['government', 'religious','ethnic', 'Animal Rights','religious', 'religious','religious', 'ethnic','ethnic', 
         'political','ethnic', 'ethnic','Incel', 'political','nationalist', 'ethnic', 'ethnic','political', 'political',
         'ethnic', 'religious','ethnic', 'ethnic', 'religious','ethnic', 'religious','Conspiracy theory', 'Feminist',
         'religious', 'religious','religious', 'ethnic', 'nationalist','religious', 'religious','government', 'ethnic',
         'ethnic', 'ethnic','political', 'political','political', 'ethnic','government', 'government','ethnic', 'Anti-LGBT', 
         'ethnic','ethnic', 'ethnic','government', 'ethnic','ethnic', 'nationalist','religious', 'ethnic','ethnic', 
         'nationalist','government', 'ethnic','Pro-choice', 'government','Anti-Abortion', 'political','government', 'ethnic',
         'Pro-LGBT Rights ', 'Court Reform','religious', 'Anti-Gun Control','nationalist', 'nationalist']

extremists = extrem_df.copy(deep=True)
for i, item in enumerate(original):
    extremists = extremists.replace(item, type_new[i])
    
# All anti- extremists are categories under the same group as pro- extremists
extremists = extremists.replace(dict.fromkeys(['Anti-religious','Sunni religious','Shia religious',
                                                              'Houthi extremists (Ansar Allah)'], ['religious']))
extremists = extremists.replace('Anti-ethnic','ethnic')

extremists = extremists.rename(columns={'Group Name':'Group Type'})

# Re-add Group Type column
extremists['Group Name'] = extrem_df['Group Name']
extremists.head()
# Out:
#        Year Code      Country          Region  Income Level  Group Type  \
# 593    2019  AFG  Afghanistan      South Asia    Low Income  government
# 5543   2016  AFG  Afghanistan      South Asia    Low Income   religious
# 8905   2014  AFG  Afghanistan      South Asia    Low Income   religious
# 14756  2016  ALB      Albania  Eastern Europe  Upper Middle   religious
# 14777  2017  ARG    Argentina   South America  Upper Middle      ethnic
#
#        Fatalities  Wounded  Casualties               Type of Target  \
# 593           0.0      0.0         0.0                      Unknown
# 5543          0.0      0.0         0.0                          NGO
# 8905          1.0      1.0         2.0          Journalists & Media
# 14756         0.0      0.0         0.0  Private Citizens & Property
# 14777         0.0      0.0         0.0                     Business
#
#                        Group Name
# 593    Anti-Government extremists
# 5543            Muslim extremists
# 8905            Muslim extremists
# 14756           Muslim extremists
# 14777          Mapuche extremists

# %%
extremists.to_csv('data/extremists_groups.csv', index=False)
